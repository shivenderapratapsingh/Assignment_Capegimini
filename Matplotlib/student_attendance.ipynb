# %%
import matplotlib.pyplot as plt

# %%
months=["Jan","Feb","Mar","Apr"]
present=[85,90,95,88]

plt.plot(months,present)
plt.title("Student Attendance")
plt.xlabel("months")
plt.ylabel("present")
plt.show()
