# %%
# Scenario: Restaurant Ordering System
# A restaurant wants to build a machine learning model to predict order preparation time.
# They collect data about each order, including:
# - Meal Type: Breakfast, Lunch, Dinner
# - Spice Level: Mild, Medium, Hot
# Since models can’t directly work with text labels, the restaurant uses Label Encoding to 
# convert these categories into numbers.

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression

data = {
    "Meal_Type": ["Breakfast", "Lunch", "Dinner", "Lunch", "Dinner", "Breakfast"],
    "Spice_Level": ["Mild", "Medium", "Hot", "Hot", "Medium", "Mild"],
    "Prep_Time": [10, 20, 35, 25, 30, 12]
}

df = pd.DataFrame(data)

le_meal = LabelEncoder()
le_spice = LabelEncoder()


df["Meal_Type"] = le_meal.fit_transform(df["Meal_Type"])
df["Spice_Level"] = le_spice.fit_transform(df["Spice_Level"])

print(df)
# Out:
#    Meal_Type  Spice_Level  Prep_Time
# 0          0            2         10
# 1          2            1         20
# 2          1            0         35
# 3          2            0         25
# 4          1            1         30
# 5          0            2         12
