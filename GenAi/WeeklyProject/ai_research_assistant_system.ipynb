# %%
# pip install langchain python-dotenv langchain-nvidia-ai-endpoints

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv

# load API key from .env
load_dotenv()

# initialize model
model = init_chat_model(
    "mistralai/devstral-2-123b-instruct-2512",
    model_provider="nvidia"
)

# sample article
article = """
Artificial Intelligence (AI) is rapidly transforming modern industries including healthcare,
education, and finance. Machine learning algorithms allow computers to learn patterns from
large datasets and make intelligent predictions. In healthcare, AI systems assist doctors in
diagnosing diseases earlier and more accurately. In education, AI helps personalize learning
experiences for students. However, the rise of AI also raises ethical concerns such as data
privacy, algorithm bias, and job displacement caused by automation.
"""

prompt = f"Summarize the following article:\n{article}"

response = model.invoke(prompt)

print(response.content)
# Out:
# **Summary:**
#
# Artificial Intelligence (AI) is revolutionizing industries like healthcare, education, and finance by enabling machines to analyze large datasets and make intelligent predictions. In healthcare, AI enhances disease diagnosis, while in education, it personalizes learning. However, ethical challenges such as data privacy, algorithmic bias, and job displacement due to automation remain key concerns.

# %%
# Task 2 – Prompt Engineering Experiments

# %%
# 1 Zero-Shot Prompt

# %%
prompt = f"""
Summarize the following article in 5 bullet points:

{article}
"""

response = model.invoke(prompt)
print(response.content)
# Out:
# - **Industry Transformation**: AI is rapidly revolutionizing sectors like healthcare, education, and finance.
# - **Machine Learning Capabilities**: AI uses algorithms to analyze large datasets and make intelligent predictions.
# - **Healthcare Impact**: AI aids doctors in earlier and more accurate disease diagnosis.
# - **Education Personalization**: AI tailors learning experiences to individual student needs.
# - **Ethical Concerns**: AI raises issues like data privacy, algorithm bias, and job displacement due to automation.

# %%
# 2 Few-Shot Prompt
prompt = f"""
Example 1
Article: Electric vehicles reduce pollution and reliance on fossil fuels.

Summary:
• EVs reduce carbon emissions
• Promote sustainable transportation
• Support renewable energy use

Example 2
Article: Climate change increases global temperatures and causes extreme weather.

Summary:
• Rising global temperatures
• Increased natural disasters
• Need for global climate policies

Now summarize the following article:

{article}
"""

response = model.invoke(prompt)
print(response.content)
# Out:
# Here’s a concise summary of the article:
#
# • **AI is transforming industries** (healthcare, education, finance)
# • **Enables pattern learning and intelligent predictions** via machine learning
# • **Boosts disease diagnosis and personalized learning**
# • **Raises ethical concerns** (privacy, bias, job displacement)

# %%
#3. Chain-of-Thought Prompt
prompt = f"""
Analyze the article step by step:

1. Identify the main topic
2. Extract key ideas
3. Generate a concise summary

Article:
{article}
"""

response = model.invoke(prompt)
print(response.content)
# Out:
# ### **Step-by-Step Analysis of the Article**
#
# #### **1. Main Topic**
# The article discusses **the impact of Artificial Intelligence (AI) on various industries** and the **opportunities and challenges** it presents.
#
# #### **2. Key Ideas**
# - **AI Transformation**: AI is reshaping industries like **healthcare, education, and finance**.
# - **Machine Learning**: AI uses algorithms to analyze **large datasets** and make **intelligent predictions**.
# - **Healthcare Applications**: AI helps doctors with **earlier and more accurate disease diagnosis**.
# - **Education Applications**: AI enables **personalized learning experiences** for students.
# - **Ethical Concerns**: Challenges include **data privacy, algorithm bias, and job displacement** due to automation.
#
# #### **3. Concise Summary**
# The article highlights how **AI is revolutionizing industries** through **machine learning**, improving healthcare diagnostics and education personalization. However, it also warns of **ethical risks**, such as privacy issues and job loss from automation.
#
# Would you like a deeper analysis of any specific aspect?

# %%
# Task 3 – Prompt Optimization
optimized_prompt = f"""
Read the article and generate a professional executive summary.

Your response must include:

1. Three key insights
2. One actionable recommendation
3. Professional tone

Article:
{article}
"""

response = model.invoke(optimized_prompt)
print(response.content)
# Out:
# ### **Executive Summary: The Impact and Challenges of Artificial Intelligence**
#
# Artificial Intelligence (AI) is driving transformative change across industries, offering significant advancements but also presenting ethical and operational challenges. This summary highlights key insights and actionable recommendations for stakeholders navigating AI adoption.
#
# #### **Key Insights:**
# 1. **Cross-Sector Transformation** – AI is revolutionizing industries such as healthcare, education, and finance by enabling data-driven decision-making, early disease detection, personalized learning, and automated financial analysis.
# 2. **Ethical and Privacy Risks** – The rapid growth of AI raises concerns, including data privacy violations, algorithmic bias (which may reinforce discrimination), and the potential displacement of jobs due to automation.
# 3. **Balancing Innovation with Responsibility** – While AI enhances efficiency and accuracy, organizations must prioritize ethical AI development, transparent governance, and proactive risk mitigation to ensure long-term sustainability.
#
# #### **Actionable Recommendation:**
# To maximize AI’s benefits while minimizing risks, organizations should **establish a multidisciplinary AI ethics board** comprising technologists, legal experts, and industry stakeholders. This board should:
# - Develop and enforce **ethical AI frameworks** to address bias, privacy, and accountability.
# - Conduct **regular audits** of AI systems to ensure fairness and compliance with regulations.
# - Implement **reskilling initiatives** to prepare employees for AI-driven workplace transitions.
#
# By adopting a proactive and responsible approach, businesses and institutions can harness AI’s potential while safeguarding against its inherent challenges.
#
# **Professional Tone:** This summary maintains a structured, objective, and forward-looking perspective, emphasizing strategic considerations for leaders in AI implementation.

# %%
# Task 4 – Tokenization Experiment
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

text = "Artificial Intelligence helps computers learn from data."

tokens = tokenizer.tokenize(text)

print("Tokens:", tokens)
print("Token Count:", len(tokens))
# Out:
# Tokens: ['artificial', 'intelligence', 'helps', 'computers', 'learn', 'from', 'data', '.']
# Token Count: 8

# %%
# Task 5 – Build a Mini AI Tool


model = init_chat_model(
    "mistralai/devstral-2-123b-instruct-2512",
    model_provider="nvidia"
)

def research_assistant(article_text):

    prompt = f"""
    Analyze the article and provide:

    1. Short Summary
    2. Key Insights
    3. One Actionable Recommendation

    Article:
    {article_text}
    """

    response = model.invoke(prompt)

    return response.content


# user input
article = input("Enter article text:\n")

result = research_assistant(article)


print("\nAI Research Assistant Output:\n")
print(result)
# Out:
# AI Research Assistant Output:
#
# Here’s a concise analysis of your input (though the article content is minimal):
#
# ### **1. Short Summary**
# The provided text consists of a single, informal greeting ("hello"), offering no substantial content to analyze.
#
# ### **2. Key Insights**
# - The input lacks meaningful information, context, or structure.
# - Without additional details, insights cannot be derived.
#
# ### **3. One Actionable Recommendation**
# If this was intended as a placeholder or draft, consider expanding the content with:
# - A clear topic or question.
# - Relevant data, arguments, or examples to analyze.
#
#  let me know if you’d like to share a full article or refine the request!
